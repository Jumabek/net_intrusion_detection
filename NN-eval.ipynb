# %%
author="Jumabek Alikhanov"
date = 'Nov 17,2019'

# %% [markdown]
# This is Final Project material for the "Deep Learning" class I took

# %% [markdown]
# ## Download the dataset from https://www.unb.ca/cic/datasets/ids-2017.html
# We only need CSV files that is preprocessed and labeled for ML

# %%
#imports
import os
from os.path import join
import glob
import pandas as pd
import numpy as np
import time
# %load_ext autoreload

# %%
# load data
dataroot = 'MachineLearningCVE/'
SEED =2 
np.random.seed(SEED)

# %%
# %autoreload 2
from preprocessing import load_data
X,y = load_data(dataroot) # reads csv file and returns np array of X,y -> of shape (N,D) and (N,1)
# Out:
# MachineLearningCVE/*.pcap_ISCX.csv
# there are 2830743 flow records with 79 feature dimension
# stripped column names
# dropped bad columns
# There are 0 nan entries
# converted to numeric

# %% [markdown]
# ## Data Imbalance
# 1. It is curucial to adress this issue in order to get decent performance
# 2. It also affects evaluation, we should calculate  `balanced accuracy`

# %%
from preprocessing import balance_data, normalize
X = normalize(X)

# %%
# %autoreload 2
from models import Classifier

def ensure_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)

def getClassifier(args=None,runs_dir=None):
    if args is not None:
        (method,optim,lr,reg,batch_size,input_dim,num_class,num_iters) = args
    if runs_dir is not None:
        ensure_dir(runs_dir)
    
    clf = Classifier(method,input_dim,num_class,lr=lr,reg=reg,num_epochs=num_iters,
                        batch_size=batch_size,runs_dir=runs_dir)
    return clf

# %%
def KFoldEvaluation(method='cnn2')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import metrics
K=5
results = {}

#hyper-params
batch_size = 5*1024 # increasing batch size with more gpu added
optim = 'Adam'

N,input_dim = X.shape
num_class = len(np.unique(y))
num_epochs = 20
num_layers = '3'
run='Kfold'
lr = 1e-3 #best_lr
reg = 1e-5 #best_reg

skf = StratifiedKFold(n_splits=K,random_state=SEED)
for fold_index, (train_index,test_index) in enumerate(skf.split(X,y)): 
        print('---------------------------------------------')
        print('Fold #{}'.format(fold_index))    
        X_train = X[train_index]
        y_train = y[train_index]
        X_test = X[test_index]
        y_test = y[test_index]
        
        X_train,y_train = balance_data(X_train,y_train,seed = SEED)
        num_iters = X_train.shape[0]*10
        classifier_args = ('nn3',optim,lr,reg,batch_size,input_dim,num_class,num_epochs)
        config =  '{}_layer_relu_nn/{}-{}th_run/optim_{}_lr_{}_reg_{}_bs_{}'.format(num_layers,run,fold_index,optim,lr,reg,batch_size)
        runs_dir = join(dataroot,'runs',config)
    
        clf = getClassifier(classifier_args,runs_dir)
        
        clf.fit(X_train,y_train)
    
        pred = clf.predict(X_test,eval_mode=True)
        test_acc = metrics.balanced_accuracy_score(y_test,pred)*100
        print('balanced test acc: ',test_acc)
        results[fold_index]= (test_acc)
# Out:
# ---------------------------------------------
# Fold #0
# building NN3
# Loaded MachineLearningCVE/runs/3_layer_relu_nn/Kfold-0th_run/optim_Adam_lr_0.001_reg_1e-05_bs_5120 model trained with batch_size = 5120, seen 4 epochs and 353 mini batches
# best epoch 5, best batch 354
# bst acc  92.05375114785531
# Epoch [6/20], Step [355/398], Loss: 0.2492
# Epoch [7/20], Step [6/398], Loss: 0.2394
# Epoch [7/20], Step [56/398], Loss: 0.2552
# Epoch [7/20], Step [106/398], Loss: 0.2480
# Epoch [7/20], Step [156/398], Loss: 0.2475
# Epoch [7/20], Step [206/398], Loss: 0.2628
# Epoch [7/20], Step [256/398], Loss: 0.2467
# Epoch [7/20], Step [306/398], Loss: 0.2453
# Epoch [7/20], Step [356/398], Loss: 0.2540
# no improvement in accuracy for 10 iterations
# Loaded MachineLearningCVE/runs/3_layer_relu_nn/Kfold-0th_run/optim_Adam_lr_0.001_reg_1e-05_bs_5120 model trained with batch_size = 5120, seen 4 epochs and 353 mini batches
# balanced test acc:  83.18824804791724
# ---------------------------------------------
# Fold #1
# building NN3
# Loaded MachineLearningCVE/runs/3_layer_relu_nn/Kfold-1th_run/optim_Adam_lr_0.001_reg_1e-05_bs_5120 model trained with batch_size = 5120, seen 1 epochs and 300 mini batches
# best epoch 2, best batch 301
# bst acc  88.73542253405019
# Epoch [3/20], Step [302/398], Loss: 0.3200
# Epoch [3/20], Step [352/398], Loss: 0.3207
# Epoch [4/20], Step [3/398], Loss: 0.3081
# Epoch [4/20], Step [53/398], Loss: 0.3179
# Epoch [4/20], Step [103/398], Loss: 0.3029
# Epoch [4/20], Step [153/398], Loss: 0.3002
# Epoch [4/20], Step [203/398], Loss: 0.3053
# Epoch [4/20], Step [253/398], Loss: 0.2826
# Epoch [4/20], Step [303/398], Loss: 0.3205
# Epoch [4/20], Step [353/398], Loss: 0.2865
# Epoch [5/20], Step [4/398], Loss: 0.3089
# Epoch [5/20], Step [54/398], Loss: 0.2775
# Epoch [5/20], Step [104/398], Loss: 0.3007
# Epoch [5/20], Step [154/398], Loss: 0.2841
# Epoch [5/20], Step [204/398], Loss: 0.2779
# Epoch [5/20], Step [254/398], Loss: 0.2800
# Epoch [5/20], Step [304/398], Loss: 0.2644
# Epoch [5/20], Step [354/398], Loss: 0.2693
# Epoch [6/20], Step [5/398], Loss: 0.2923
# Epoch [6/20], Step [55/398], Loss: 0.2606
# Epoch [6/20], Step [105/398], Loss: 0.2584
# Epoch [6/20], Step [155/398], Loss: 0.2628
# Epoch [6/20], Step [205/398], Loss: 0.2685
# Epoch [6/20], Step [255/398], Loss: 0.2577
# Epoch [6/20], Step [305/398], Loss: 0.2628
# Epoch [6/20], Step [355/398], Loss: 0.2729
# Epoch [7/20], Step [6/398], Loss: 0.2785
# Epoch [7/20], Step [56/398], Loss: 0.2594
# Epoch [7/20], Step [106/398], Loss: 0.2645
# Epoch [7/20], Step [156/398], Loss: 0.2506
# Epoch [7/20], Step [206/398], Loss: 0.2560
# no improvement in accuracy for 10 iterations
# Loaded MachineLearningCVE/runs/3_layer_relu_nn/Kfold-1th_run/optim_Adam_lr_0.001_reg_1e-05_bs_5120 model trained with batch_size = 5120, seen 5 epochs and 154 mini batches
# balanced test acc:  86.8745767758903
# ---------------------------------------------
# Fold #2
# building NN3
# best epoch 0, best batch 0
# bst acc  -1
# Epoch [1/20], Step [50/398], Loss: 1.0659
# Epoch [1/20], Step [100/398], Loss: 0.6586
# Epoch [1/20], Step [150/398], Loss: 0.5595
# Epoch [1/20], Step [200/398], Loss: 0.4622
# Epoch [1/20], Step [250/398], Loss: 0.4516
# Epoch [1/20], Step [300/398], Loss: 0.4291
# Epoch [1/20], Step [350/398], Loss: 0.3845
# Epoch [2/20], Step [1/398], Loss: 0.3616
# Epoch [2/20], Step [51/398], Loss: 0.4075
# Epoch [2/20], Step [101/398], Loss: 0.3366
# Epoch [10/20], Step [9/398], Loss: 0.2225
# Epoch [10/20], Step [59/398], Loss: 0.2313
# Epoch [10/20], Step [109/398], Loss: 0.2212
# Epoch [10/20], Step [159/398], Loss: 0.2248
# Epoch [10/20], Step [209/398], Loss: 0.2298
# Epoch [10/20], Step [259/398], Loss: 0.2202
# Epoch [10/20], Step [309/398], Loss: 0.2112
# Epoch [10/20], Step [359/398], Loss: 0.2291
# Epoch [11/20], Step [10/398], Loss: 0.2463
# Epoch [11/20], Step [60/398], Loss: 0.2109
# Epoch [11/20], Step [110/398], Loss: 0.2128
# Epoch [11/20], Step [160/398], Loss: 0.2397
# Epoch [11/20], Step [210/398], Loss: 0.2180
# Epoch [11/20], Step [260/398], Loss: 0.2451
# Epoch [11/20], Step [310/398], Loss: 0.2081
# Epoch [11/20], Step [360/398], Loss: 0.2178
# Epoch [12/20], Step [11/398], Loss: 0.2444
# Epoch [12/20], Step [61/398], Loss: 0.2109
# Epoch [12/20], Step [111/398], Loss: 0.2285
# Epoch [12/20], Step [161/398], Loss: 0.2114
# Epoch [12/20], Step [211/398], Loss: 0.2322
# Epoch [12/20], Step [261/398], Loss: 0.2417
# Epoch [12/20], Step [311/398], Loss: 0.2106
# Epoch [12/20], Step [361/398], Loss: 0.2339
# Epoch [13/20], Step [12/398], Loss: 0.2225
# Epoch [13/20], Step [62/398], Loss: 0.2085
# Epoch [13/20], Step [112/398], Loss: 0.2180
# Epoch [13/20], Step [162/398], Loss: 0.2146
# Epoch [13/20], Step [212/398], Loss: 0.2046
# Epoch [13/20], Step [262/398], Loss: 0.1990
# Epoch [13/20], Step [312/398], Loss: 0.2108
# Epoch [13/20], Step [362/398], Loss: 0.2294
# Epoch [14/20], Step [13/398], Loss: 0.2057
# Epoch [14/20], Step [63/398], Loss: 0.2072
# Epoch [14/20], Step [113/398], Loss: 0.2199
# Epoch [14/20], Step [163/398], Loss: 0.2345
# Epoch [14/20], Step [213/398], Loss: 0.2055
# Epoch [14/20], Step [263/398], Loss: 0.2236
# Epoch [14/20], Step [313/398], Loss: 0.2138
# Epoch [14/20], Step [363/398], Loss: 0.2413
# Epoch [15/20], Step [14/398], Loss: 0.2013
# Epoch [15/20], Step [64/398], Loss: 0.1961
# no improvement in accuracy for 10 iterations
# Loaded MachineLearningCVE/runs/3_layer_relu_nn/Kfold-2th_run/optim_Adam_lr_0.001_reg_1e-05_bs_5120 model trained with batch_size = 5120, seen 13 epochs and 12 mini batches
# balanced test acc:  88.33117090827255
# ---------------------------------------------
# Fold #3
# building NN3
# best epoch 0, best batch 0
# bst acc  -1
# Epoch [1/20], Step [50/398], Loss: 1.0958
# Epoch [1/20], Step [100/398], Loss: 0.6942
# Epoch [1/20], Step [150/398], Loss: 0.5796
# Epoch [1/20], Step [200/398], Loss: 0.5210
# Epoch [1/20], Step [250/398], Loss: 0.4882
# Epoch [1/20], Step [300/398], Loss: 0.4501
# Epoch [1/20], Step [350/398], Loss: 0.4156
# Epoch [2/20], Step [1/398], Loss: 0.4263

# %%
sum_test_acc = 0
for fold_index,res in results.items():
    (test_acc) = res
    sum_test_acc+= test_acc
print("{}-fold evaluation:".format(K))
print('test acc: ',sum_test_acc/K)
print('{0:.2f}'.format(sum_test_acc/K))
